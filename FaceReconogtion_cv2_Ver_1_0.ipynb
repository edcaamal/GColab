# %% [markdown]
# <a href="https://colab.research.google.com/github/edcaamal/GColab/blob/main/FaceReconogtion_cv2_Ver_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Reconocimiento de Rostros con cv2 Ver 1-0

# %%
# Link apoyo
# https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
# Comprobamos archvios cargados
# .Xml
# imagenes para procesar
# .jpg, .jpeg, .png


# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Apr  7 13:36 sample_data

# %%
import cv2
from google.colab.patches import cv2_imshow

#Cargamos nuestro classificador :
#cascada_rostro = cv2.CascadeClassifier('haarcascade_frontalcatface_extended.xml')

cascada_rostro = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
#Cargamos la imagen y la convertimos a grises:
img = cv2.imread('Alumnos.png')
img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#Buscamos los rostros:
coordenadas_rostros = cascada_rostro.detectMultiScale(img_gris, 1.3, 2)

# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')


#Marcamos todos los gatos de la imagen:
for (x,y,ancho, alto) in coordenadas_rostros:
    cv2.rectangle(img, (x,y), (x+ancho, y+alto), (0,255,0) , 3)

# %%
#Abrimos una ventana con el resultado:

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2498x1554 at 0x7FDBBC346B50>
